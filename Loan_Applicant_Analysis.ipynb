# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Reading CSV File

# %%
df=pd.read_csv('Applicant-details.csv')

# %% [markdown]
# # Data Exploration

# %%
df.head()
# Out:
#    Applicant_ID  Annual_Income  Applicant_Age  Work_Experience Marital_Status  \
# 0         75722        9657655             76                0         single
# 1         80185        9259353             37               18         single
# 2         19865        1509721             66                8         single
# 3         76700        5867312             43                1         single
# 4         92992        7223191             44                9         single
#
#   House_Ownership Vehicle_Ownership(car)              Occupation  \
# 0          rented                     no            Psychologist
# 1          rented                     no      Petroleum_Engineer
# 2          rented                     no                 Drafter
# 3           owned                     no    Chartered_Accountant
# 4          rented                     no  Air_traffic_controller
#
#   Residence_City Residence_State  Years_in_Current_Employment  \
# ...

# %%
#Changing column name in Top Buy table
new_col ={"Applicant_ID":"ID"}
df=df.rename(columns=new_col)
df.head()
# Out:
#       ID  Annual_Income  Applicant_Age  Work_Experience Marital_Status  \
# 0  75722        9657655             76                0         single
# 1  80185        9259353             37               18         single
# 2  19865        1509721             66                8         single
# 3  76700        5867312             43                1         single
# 4  92992        7223191             44                9         single
#
#   House_Ownership Vehicle_Ownership(car)              Occupation  \
# 0          rented                     no            Psychologist
# 1          rented                     no      Petroleum_Engineer
# 2          rented                     no                 Drafter
# 3           owned                     no    Chartered_Accountant
# 4          rented                     no  Air_traffic_controller
#
#   Residence_City Residence_State  Years_in_Current_Employment  \
# 0      Jalandhar          Punjab                            0
# ...

# %% [markdown]
# # Data Cleaning

# %%
df.isna()
# Out:
#           ID  Annual_Income  Applicant_Age  Work_Experience  Marital_Status  \
# 0      False          False          False            False           False
# 1      False          False          False            False           False
# 2      False          False          False            False           False
# 3      False          False          False            False           False
# 4      False          False          False            False           False
# ...      ...            ...            ...              ...             ...
# 99995  False          False          False            False           False
# 99996  False          False          False            False           False
# 99997  False          False          False            False           False
# 99998  False          False          False            False           False
# 99999  False          False          False            False           False
#
# ...

# %%
df.isnull().any()
# Out:
# ID                             False
# Annual_Income                  False
# Applicant_Age                  False
# Work_Experience                False
# Marital_Status                 False
# House_Ownership                False
# Vehicle_Ownership(car)         False
# Occupation                     False
# Residence_City                 False
# Residence_State                False
# Years_in_Current_Employment    False
# Years_in_Current_Residence     False
# Loan_Default_Risk              False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   ID                           100000 non-null  int64
#  1   Annual_Income                100000 non-null  int64
#  2   Applicant_Age                100000 non-null  int64
#  3   Work_Experience              100000 non-null  int64
#  4   Marital_Status               100000 non-null  object
#  5   House_Ownership              100000 non-null  object
#  6   Vehicle_Ownership(car)       100000 non-null  object
#  7   Occupation                   100000 non-null  object
#  8   Residence_City               100000 non-null  object
#  9   Residence_State              100000 non-null  object
#  10  Years_in_Current_Employment  100000 non-null  int64
#  11  Years_in_Current_Residence   100000 non-null  int64
# ...

# %% [markdown]
# # Average work experience of loan applicant according to occupation

# %%
workex=df.groupby("Occupation")["Work_Experience"].mean()
workex.sort_values(ascending = False)
# Out:
# Occupation
# Drafter                       11.073136
# Firefighter                   11.002833
# Army_officer                  10.987090
# Secretary                     10.986301
# Physician                     10.853256
# Statistician                  10.728828
# Fashion_Designer              10.690726
# Financial_Analyst             10.680616
# Magistrate                    10.652835
# Official                      10.637775
# Design_Engineer               10.570652
# Psychologist                  10.509598
# Microbiologist                10.505214
# Architect                     10.486472
# Computer_operator             10.418616
# Artist                        10.261280
# Biomedical_Engineer           10.223149
# Comedian                      10.210176
# Web_designer                  10.181607
# Economist                     10.163944
# Analyst                       10.163008
# Chef                          10.149476
# Consultant                    10.138148
# ...

# %%
workex.plot(kind="bar", ylabel="Work Experience(Years)", xlabel="Occupation", title="Avg Work-Ex of a Applicant", figsize=(12,8))
# Out:
# <Axes: title={'center': 'Avg Work-Ex of a Applicant'}, xlabel='Occupation', ylabel='Work Experience(Years)'>

# %% [markdown]
# # Average age of applicants according to occupation

# %%
mode_age = df.groupby("Occupation")["Applicant_Age"].mean()
age.sort_values(ascending = False)
# Out:
# Occupation
# Chartered_Accountant          56.0
# Computer_operator             56.0
# Civil_servant                 55.0
# Financial_Analyst             55.0
# Dentist                       54.0
# Artist                        53.5
# Air_traffic_controller        53.0
# Aviator                       53.0
# Army_officer                  53.0
# Design_Engineer               52.0
# Economist                     52.0
# Drafter                       52.0
# Physician                     52.0
# Geologist                     52.0
# Technical_writer              51.5
# Hotel_Manager                 51.0
# Designer                      51.0
# Engineer                      51.0
# Lawyer                        50.0
# Surveyor                      50.0
# Software_Developer            50.0
# Fashion_Designer              50.0
# Technology_specialist         50.0
# Psychologist                  50.0
# Politician                    50.0
# Biomedical_Engineer           50.0
# ...

# %%
plt=age.plot(kind="bar",ylabel="Mean Age",xlabel="Occupation",title="Avg age of a applicant",figsize=(15,6))

# %% [markdown]
# # Number of unique values in each column

# %%
cat=df.select_dtypes(include='object')
cat.head()
# Out:
#   Marital_Status House_Ownership Vehicle_Ownership(car)  \
# 0         single          rented                     no
# 1         single          rented                     no
# 2         single          rented                     no
# 3         single           owned                     no
# 4         single          rented                     no
#
#                Occupation Residence_City Residence_State
# 0            Psychologist      Jalandhar          Punjab
# 1      Petroleum_Engineer          Bally     West_Bengal
# 2                 Drafter         Indore  Madhya_Pradesh
# 3    Chartered_Accountant    Kurnool[18]  Andhra_Pradesh
# 4  Air_traffic_controller        Asansol     West_Bengal

# %%
cat.nunique()
# Out:
# Marital_Status              2
# House_Ownership             3
# Vehicle_Ownership(car)      2
# Occupation                 51
# Residence_City            317
# Residence_State            29
# dtype: int64

# %% [markdown]
# # Minimum salary of loan appliant according to state

# %%
income=df.groupby("Residence_State")["Annual_Income"].min()
income.sort_values(ascending = False)
# Out:
# Residence_State
# Chandigarh           881669
# Tripura              612456
# Uttar_Pradesh[5]     461499
# Manipur              373596
# Mizoram              340023
# Puducherry           268562
# Kerala               210054
# Odisha               206151
# Sikkim               129457
# Chhattisgarh         112513
# Himachal_Pradesh      96503
# Madhya_Pradesh        88025
# Karnataka             84792
# Jammu_and_Kashmir     80183
# Punjab                66912
# Assam                 61638
# Bihar                 61219
# Haryana               52436
# Rajasthan             41719
# Delhi                 36391
# Gujarat               30515
# Jharkhand             28561
# Tamil_Nadu            21831
# Uttar_Pradesh         16890
# Uttarakhand           12608
# Maharashtra           11430
# Andhra_Pradesh        11114
# Telangana             10675
# West_Bengal           10310
# Name: Annual_Income, dtype: int64

# %%
income.plot(kind="bar", ylabel="Annual Income", xlabel="State", title="Minimum Salary of Loan Applicants", figsize=(12, 6), colormap='plasma')
# Out:
# <Axes: title={'center': 'Minimum Salary of Loan Applicants'}, xlabel='State', ylabel='Annual Income'>
